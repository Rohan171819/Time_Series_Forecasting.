# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan171819/Time_Series_Forecasting./blob/main/Time_Series_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/rainfall in india 1901-2015.csv")

# %%
data.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# ...

# %%
data.plot()
# Out:
# <Axes: >

# %%
data.plot(ls="--")
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
from datetime import datetime

# %%
data=data.set_index(data["YEAR"])

# %%
data.head()
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# YEAR
# 1901  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1902  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 1903  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 1904  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 1905  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#         JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# YEAR
# 1901  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1902  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 1903  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 1904  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 1905  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#       Jun-Sep  Oct-Dec
# YEAR
# ...

# %%
data["ANNUAL"].rolling(50).mean()
# Out:
# YEAR
# 1901         NaN
# 1902         NaN
# 1903         NaN
# 1904         NaN
# 1905         NaN
#           ...
# 2011    1589.672
# 2012    1586.050
# 2013    1576.534
# 2014    1571.400
# 2015    1576.140
# Name: ANNUAL, Length: 4116, dtype: float64

# %%
data["ANNUAL"].rolling(50).mean().plot(ls="--",c="black")
# Out:
# <Axes: xlabel='YEAR'>

# %%
data["ANNUAL"].rolling(50).max()
# Out:
# YEAR
# 1901       NaN
# 1902       NaN
# 1903       NaN
# 1904       NaN
# 1905       NaN
#          ...
# 2011    2361.6
# 2012    2361.6
# 2013    2361.6
# 2014    2361.6
# 2015    2361.6
# Name: ANNUAL, Length: 4116, dtype: float64

# %%
data["ANNUAL"].rolling(50).max().plot(c="black",ls="--")
# Out:
# <Axes: xlabel='YEAR'>

# %%
data["ANNUAL"].rolling(50).min()
# Out:
# YEAR
# 1901       NaN
# 1902       NaN
# 1903       NaN
# 1904       NaN
# 1905       NaN
#          ...
# 2011    1033.5
# 2012    1033.5
# 2013    1033.5
# 2014    1033.5
# 2015    1033.5
# Name: ANNUAL, Length: 4116, dtype: float64

# %%
data["ANNUAL"].rolling(50).min().plot(c="black",ls="--")
# Out:
# <Axes: xlabel='YEAR'>

# %%
data["ANNUAL: 50 YEARS ROLLING"]=data[["ANNUAL"]].rolling(50).mean()

# %%
data[["ANNUAL","ANNUAL: 50 YEARS ROLLING"]].plot()
# Out:
# <Axes: xlabel='YEAR'>
